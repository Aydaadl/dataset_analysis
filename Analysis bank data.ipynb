# %% [markdown]
# <a href="https://colab.research.google.com/github/Aydaadl/dataset_analysis/blob/main/Analysis%20bank%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Analysis bank data/dictionary_selected.csv")

# %%
df
# Out:
#                         feature  \
# 0                     out_prncp
# 1               total_rec_prncp
# 2                 total_rec_int
# 3            total_rec_late_fee
# 4                    recoveries
# 5               last_pymnt_amnt
# 6          debt_settlement_flag
# 7                     int_rate%
# 8                      loan_age
# 9       time_since_last_payment
# 10  time_since_last_credit_pull
# 11       loan_amnt_div_instlmnt
#
#                                           description
# 0   Remaining outstanding principal for total amou...
# 1                          Principal received to date
# 2                           Interest received to date
# 3                          Late fees received to date
# 4                      post charge off gross recovery
# 5                  Last total payment amount received
# 6                    the debt has/hasn't been settled
# 7             Interest Rate on the loan in percentage
# ...

# %%
df.head()
# Out:
#               feature                                        description
# 0           out_prncp  Remaining outstanding principal for total amou...
# 1     total_rec_prncp                         Principal received to date
# 2       total_rec_int                          Interest received to date
# 3  total_rec_late_fee                         Late fees received to date
# 4          recoveries                     post charge off gross recovery

# %%
df.shape
# Out:
# (12, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   feature      12 non-null     object
#  1   description  12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#           feature                                        description
# count          12                                                 12
# unique         12                                                 12
# top     out_prncp  Remaining outstanding principal for total amou...
# freq            1                                                  1

# %%
df.isnull()
# Out:
#     feature  description
# 0     False        False
# 1     False        False
# 2     False        False
# 3     False        False
# 4     False        False
# 5     False        False
# 6     False        False
# 7     False        False
# 8     False        False
# 9     False        False
# 10    False        False
# 11    False        False

# %%
df1=pd.read_csv("/content/drive/MyDrive/Analysis bank data/df_2014-18_selected (1).csv")

# %%
df2=pd.read_csv("/content/drive/MyDrive/Analysis bank data/loan_2019_20.csv")
# Out:
# /tmp/ipython-input-22-88034685.py:1: DtypeWarning: Columns (137) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("/content/drive/MyDrive/Analysis bank data/loan_2019_20.csv")

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date',
#        'hardship_length', 'hardship_dpd', 'hardship_loan_status',
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'debt_settlement_flag'],
#       dtype='object', length=142)

# %%
df2.describe()
# Out:
#           Unnamed: 0            id      loan_amnt    funded_amnt  \
# count  664824.000000  6.648240e+05  664824.000000  664824.000000
# mean    59788.513119  1.573627e+08   16419.169246   16419.169246
# std     38084.736456  7.141676e+06   10328.408685   10328.408685
# min         0.000000  8.597283e+06    1000.000000    1000.000000
# 25%     25483.000000  1.510571e+08    8500.000000    8500.000000
# 50%     58141.000000  1.572487e+08   14400.000000   14400.000000
# 75%     91382.000000  1.632074e+08   23000.000000   23000.000000
# max    143034.000000  1.710171e+08   40000.000000   40000.000000
#
#        funded_amnt_inv    installment    annual_inc            dti  \
# count    664824.000000  664824.000000  6.648240e+05  663427.000000
# mean      16416.641490     474.811153  8.655052e+04      20.904595
# std       10329.018233     290.622992  1.081988e+05      20.005157
# min         725.000000      28.770000  0.000000e+00       0.000000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664824 entries, 0 to 664823
# Columns: 142 entries, Unnamed: 0 to debt_settlement_flag
# dtypes: float64(106), int64(2), object(34)
# memory usage: 720.3+ MB

# %%
df.isnull()
# Out:
#          total_rec_late_fee  recoveries  last_pymnt_amnt  \
# 0                     False       False            False
# 1                     False       False            False
# 2                     False       False            False
# 3                     False       False            False
# 4                     False       False            False
# ...                     ...         ...              ...
# 2029947               False       False            False
# 2029948               False       False            False
# 2029949               False       False            False
# 2029950               False       False            False
# 2029951               False       False            False
#
#          loan_amnt_div_instlmnt  debt_settlement_flag  loan_age  \
# 0                         False                 False     False
# 1                         False                 False     False
# 2                         False                 False     False
# ...

# %%
df2.dtypes
# Out:
# Unnamed: 0                                      int64
# id                                              int64
# loan_amnt                                     float64
# funded_amnt                                   float64
# funded_amnt_inv                               float64
#                                                ...
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# debt_settlement_flag                           object
# Length: 142, dtype: object

# %%
correlate=df2.corr(numeric_only=True)['loan_amnt'].sort_values(ascending=True)

# %%
correlate
# Out:
# il_util                 -0.086128
# num_accts_ever_120_pd   -0.065113
# pub_rec                 -0.061630
# pub_rec_bankruptcies    -0.061537
# open_rv_12m             -0.051463
#                            ...
# funded_amnt_inv          0.999994
# funded_amnt              1.000000
# loan_amnt                1.000000
# policy_code                   NaN
# tax_liens                     NaN
# Name: loan_amnt, Length: 108, dtype: float64

# %%
correlate1=df2.corr(numeric_only=True)['annual_inc'].sort_values(ascending=True)

# %%
correlate1
# Out:
# dti_joint               -0.116074
# dti                     -0.105990
# mths_since_rcnt_il      -0.058095
# mths_since_recent_inq   -0.042911
# mo_sin_rcnt_tl          -0.034997
#                            ...
# tot_hi_cred_lim          0.299592
# annual_inc_joint         0.768088
# annual_inc               1.000000
# policy_code                   NaN
# tax_liens                     NaN
# Name: annual_inc, Length: 108, dtype: float64

# %%
plt.figure(figsize=(10,10))

# %%
corr_m=df2.corr(numeric_only=True)
sns.heatmap(corr_m, annot=True, fmt=".2f")
plt.title("matrix corr")
# Out:
# Text(0.5, 1.0, 'matrix corr')
